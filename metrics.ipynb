# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_vgg19 = pd.read_csv('/nas/home/gujiashe/exp/SRGAN/statistics/srf_2_vgg19_train_results.csv')
results_MDFloss = pd.read_csv('/nas/home/gujiashe/exp/SRGAN/statistics/srf_2_MDFloss_train_results.csv')

# %%
results_vgg19
# Out:
#     Epoch    Loss_D    Loss_G   Score_D   Score_G       PSNR      SSIM
# 0       1  0.909850  0.044081  0.565512  0.446426  17.747594  0.395239
# 1       2  0.939043  0.023219  0.340030  0.258451  18.841144  0.494508
# 2       3  0.980034  0.022791  0.386623  0.329442  21.498670  0.569848
# 3       4  1.000036  0.018397  0.000106  0.000082  20.670771  0.647991
# 4       5  1.000015  0.015278  0.000063  0.000078  22.739857  0.687577
# ..    ...       ...       ...       ...       ...        ...       ...
# 95     96  1.000000  0.004206  0.000005  0.000004  27.595918  0.869077
# 96     97  1.000000  0.004246  0.000004  0.000004  27.267030  0.867933
# 97     98  1.000000  0.004114  0.000004  0.000004  27.617617  0.871740
# 98     99  1.000000  0.004290  0.000004  0.000004  27.494085  0.867683
# 99    100  1.000000  0.003966  0.000005  0.000005  26.268933  0.868001
#
# [100 rows x 7 columns]
