# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results_vgg19 = pd.read_csv('/nas/home/gujiashe/exp/SRGAN/statistics/srf_2_VGG19_train_results.csv')
results_MDFloss = pd.read_csv('/nas/home/gujiashe/exp/SRGAN/statistics/srf_2_MDFloss_train_results.csv')

# %%
plt.plot(results_vgg19['PSNR'])
plt.title("PSNR of SRGAN with VGG19 percetual loss")
plt.xlabel('epoch')
plt.ylabel('PSNR')
plt.savefig('/nas/home/gujiashe/exp/SRGAN/plot/PSNR_VGG19.png')

# %%
plt.plot(results_vgg19['SSIM'])
plt.title("SSIM of SRGAN with VGG19 percetual loss")
plt.xlabel('epoch')
plt.ylabel('SSIM')
plt.savefig('/nas/home/gujiashe/exp/SRGAN/plot/SSIM_VGG19.png')

# %%
plt.plot(results_MDFloss['PSNR'])
plt.title("PSNR of SRGAN with MDFloss percetual loss")
plt.xlabel('epoch')
plt.ylabel('PSNR')
plt.savefig('/nas/home/gujiashe/exp/SRGAN/plot/PSNR_MDFloss.png')

# %%
plt.plot(results_MDFloss['SSIM'])
plt.title("SSIM of SRGAN with MDFloss percetual loss")
plt.xlabel('epoch')
plt.ylabel('SSIM')
plt.savefig('/nas/home/gujiashe/exp/SRGAN/plot/SSIM_MDFloss.png')
